# %% [markdown]
# <a href="https://colab.research.google.com/github/SandhyaSingh-research/hiv-medgemma-impact/blob/main/run_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧬 ARC Framework Demo
# HIV-1 Drug Resistance Prediction

# %%
# !git clone https://github.com/SandhyaSingh-research/Interpretable-Context-Aware-HIV-Drug-Resistance-Prediction-ARC-Framework-.git
# %cd Interpretable-Context-Aware-HIV-Drug-Resistance-Prediction-ARC-Framework-
# Out:
# Cloning into 'Interpretable-Context-Aware-HIV-Drug-Resistance-Prediction-ARC-Framework-'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'Interpretable-Context-Aware-HIV-Drug-Resistance-Prediction-ARC-Framework-'
# /content

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python src/predict.py
# Out:
# python3: can't open file '/content/src/predict.py': [Errno 2] No such file or directory

# %%
import pandas as pd
df = pd.read_csv("results/predictions.csv")
df.head()

# %%
import pandas as pd
df = pd.read_csv("results/predictions.csv")
df.head()
